# %%
import pandas as pd

# %%
df=pd.read_csv('shopping_trends_updated.csv')

# %%
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
def clean_h(val):
    if isinstance(val,str):
        val="".join(char for char in val if char.isalnum() or char in (" ","_"))
        val=val.strip().lower().replace(" ","_")
        return val
    else: 
       return val
df=df.rename(columns=clean_h)
df
# Out:
#       customer_id  age  gender item_purchased     category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       purchase_amount_usd       location size      color  season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# ...

# %%
df.describe()
# Out:
#        customer_id          age  purchase_amount_usd  review_rating  \
# count  3900.000000  3900.000000          3900.000000    3900.000000
# mean   1950.500000    44.068462            59.764359       3.749949
# std    1125.977353    15.207589            23.685392       0.716223
# min       1.000000    18.000000            20.000000       2.500000
# 25%     975.750000    31.000000            39.000000       3.100000
# 50%    1950.500000    44.000000            60.000000       3.700000
# 75%    2925.250000    57.000000            81.000000       4.400000
# max    3900.000000    70.000000           100.000000       5.000000
#
#        previous_purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
df.dtypes
# Out:
# customer_id                 int64
# age                         int64
# gender                     object
# item_purchased             object
# category                   object
# purchase_amount_usd         int64
# location                   object
# size                       object
# color                      object
# season                     object
# review_rating             float64
# subscription_status        object
# shipping_type              object
# discount_applied           object
# promo_code_used            object
# previous_purchases          int64
# payment_method             object
# frequency_of_purchases     object
# dtype: object

# %%
df['customer_id']=df['customer_id'].astype(object)

# %%
df.dtypes
# Out:
# customer_id                object
# age                         int64
# gender                     object
# item_purchased             object
# category                   object
# purchase_amount_usd         int64
# location                   object
# size                       object
# color                      object
# season                     object
# review_rating             float64
# subscription_status        object
# shipping_type              object
# discount_applied           object
# promo_code_used            object
# previous_purchases          int64
# payment_method             object
# frequency_of_purchases     object
# dtype: object

# %%
df.describe()
# Out:
#                age  purchase_amount_usd  review_rating  previous_purchases
# count  3900.000000          3900.000000    3900.000000         3900.000000
# mean     44.068462            59.764359       3.749949           25.351538
# std      15.207589            23.685392       0.716223           14.447125
# min      18.000000            20.000000       2.500000            1.000000
# 25%      31.000000            39.000000       3.100000           13.000000
# 50%      44.000000            60.000000       3.700000           25.000000
# 75%      57.000000            81.000000       4.400000           38.000000
# max      70.000000           100.000000       5.000000           50.000000

# %%
df['age'].mean()
# Out:
# 44.06846153846154

# %%
df['category'][280]
# Out:
# 'Footwear'

# %%
df.head()
# Out:
#   customer_id  age gender item_purchased  category  purchase_amount_usd  \
# 0           1   55   Male         Blouse  Clothing                   53
# 1           2   19   Male        Sweater  Clothing                   64
# 2           3   50   Male          Jeans  Clothing                   73
# 3           4   21   Male        Sandals  Footwear                   90
# 4           5   45   Male         Blouse  Clothing                   49
#
#         location size      color  season  review_rating subscription_status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    shipping_type discount_applied promo_code_used  previous_purchases  \
# ...

# %%
df.tail()
# Out:
#      customer_id  age  gender item_purchased     category  \
# 3895        3896   40  Female         Hoodie     Clothing
# 3896        3897   52  Female       Backpack  Accessories
# 3897        3898   46  Female           Belt  Accessories
# 3898        3899   44  Female          Shoes     Footwear
# 3899        3900   52  Female        Handbag  Accessories
#
#       purchase_amount_usd    location size      color  season  review_rating  \
# 3895                   28    Virginia    L  Turquoise  Summer            4.2
# 3896                   49        Iowa    L      White  Spring            4.5
# 3897                   33  New Jersey    L      Green  Spring            2.9
# 3898                   77   Minnesota    S      Brown  Summer            3.8
# 3899                   81  California    M      Beige  Spring            3.1
#
#      subscription_status   shipping_type discount_applied promo_code_used  \
# 3895                  No  2-Day Shipping               No              No
# ...

# %%
df.loc[280]
# Out:
# customer_id                          281
# age                                   45
# gender                              Male
# item_purchased                   Sandals
# category                        Footwear
# purchase_amount_usd                   69
# location                         Montana
# size                                   S
# color                               Cyan
# season                              Fall
# review_rating                        4.2
# subscription_status                  Yes
# shipping_type             2-Day Shipping
# discount_applied                     Yes
# promo_code_used                      Yes
# previous_purchases                    21
# payment_method                      Cash
# frequency_of_purchases         Bi-Weekly
# Name: 280, dtype: object

# %%
df.sample(8)
# Out:
#      customer_id  age  gender item_purchased     category  \
# 2877        2878   32  Female          Socks     Clothing
# 3813        3814   61  Female          Pants     Clothing
# 347          348   36    Male        Sandals     Footwear
# 3431        3432   46  Female           Belt  Accessories
# 46            47   57    Male          Shirt     Clothing
# 1775        1776   18    Male         Jacket    Outerwear
# 3814        3815   45  Female          Dress     Clothing
# 372          373   24    Male        Sweater     Clothing
#
#       purchase_amount_usd      location size   color  season  review_rating  \
# 2877                   46    New Jersey    M  Silver  Summer            3.6
# 3813                   89       Georgia    M  Orange  Summer            4.1
# 347                    41        Oregon    L     Red    Fall            3.9
# 3431                   49    New Mexico    S   Green  Summer            4.2
# ...

# %%
df.nunique()
# Out:
# customer_id               3900
# age                         53
# gender                       2
# item_purchased              25
# category                     4
# purchase_amount_usd         81
# location                    50
# size                         4
# color                       25
# season                       4
# review_rating               26
# subscription_status          2
# shipping_type                6
# discount_applied             2
# promo_code_used              2
# previous_purchases          50
# payment_method               6
# frequency_of_purchases       7
# dtype: int64

# %%
list_review = ['good' if review_rating > 3.0 else 'bad' for review_rating in df.review_rating]
df['reviews_kinds']=list_review

# %%
df
# Out:
#      customer_id  age  gender item_purchased     category  \
# 0              1   55    Male         Blouse     Clothing
# 1              2   19    Male        Sweater     Clothing
# 2              3   50    Male          Jeans     Clothing
# 3              4   21    Male        Sandals     Footwear
# 4              5   45    Male         Blouse     Clothing
# ...          ...  ...     ...            ...          ...
# 3895        3896   40  Female         Hoodie     Clothing
# 3896        3897   52  Female       Backpack  Accessories
# 3897        3898   46  Female           Belt  Accessories
# 3898        3899   44  Female          Shoes     Footwear
# 3899        3900   52  Female        Handbag  Accessories
#
#       purchase_amount_usd       location size      color  season  \
# 0                      53       Kentucky    L       Gray  Winter
# 1                      64          Maine    L     Maroon  Winter
# 2                      73  Massachusetts    S     Maroon  Spring
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy  as np

# %%
plt.plot('frequency_of_purchases',
            'gender',
           data=df)
plt.show()

# %%
x=[]
x=df['review_rating']
y=[]
y=df['reviews_kinds']

plt.scatter(x,y)
plt.show()
